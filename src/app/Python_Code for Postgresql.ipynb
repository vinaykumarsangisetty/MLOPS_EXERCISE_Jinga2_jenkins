# %%
# import packages
# !pip install psycopg2
import psycopg2
import pandas as pd
from sqlalchemy import create_engine

# establish connections
# #INPUT YOUR OWN CONNECTION STRING HERE

conn_string = 'postgresql://username:writeyourpassword@hostname:5432/databasename'
# example: conn_string = 'postgresql://XXXXX@stsdatabase:password@stsdatabase.postgres.database.azure.com:5432/sts_database'

db = create_engine(conn_string,connect_args={'sslmode':'require'})
conn = db.connect()
conn1 = psycopg2.connect(
    database="sts_database",
    user='XXXXXX@stsdatabase',
    password='XXXXXXXXX',
    host='stsdatabase.postgres.database.azure.com',
    port= '5432'
    )

conn1.autocommit = True
cursor = conn1.cursor()

# drop table if it already exists
cursor.execute('drop table if exists dubai_tble')

sql = '''CREATE TABLE "sts_dubai_table" (
	"category_id" varchar(200),
	"project" varchar(200),
	"country" varchar(200),
	"fleet" varchar(200),
	"subsystem" varchar(200),
	"database" varchar(200),
	"observation_category" varchar(2000),
	"obs_id" varchar(200),
	"observation" text,
	"failure_class" varchar(200),
	"problem_code" varchar(200),
	"problem_cause" text,
	"problem_remedy" text,
	"functional_location" varchar(200),
	"notifications_number" varchar(200),
	"date" varchar(200),
	"solution_category" varchar(2000),
	"solution" text,
	"pbs_code" varchar(200),
	"symptom_code" varchar(200),
	"root_cause" varchar(200),
	"document_link" text,
	"language" varchar(200),
	"resource" integer,
	"min_resources_need" integer,
	"max_resource_need" integer,
	"the_most_frequent_value_for_resource" integer,
	"time" double precision,
	"min_time_per_one_person" double precision,
	"max_time_per_one_person" double precision,
	"average_time" double precision,
	"frequency_obs" double precision,
	"frequency_sol" double precision,
	"min_resources_need_sol" integer,
	"max_resource_need_sol" integer,
	"the_most_frequent_value_for_resource_sol" integer,
	"min_time_per_one_person_sol" double precision,
	"max_time_per_one_person_sol" double precision,
	"average_time_sol" double precision,
	"obs_rating" integer,
	"no_times_obs_rated" bigint,
	"obs_cat_rating" integer,
	"no_times_obs_cat_rated" bigint,
	"sol_category_id" varchar(200),
	"obs_translated" text,
	"tagged" text,
	"entity" text,
	"desc" text
)'''


cursor.execute(sql)

# import the csv file to create a dataframe
data = df.copy()

# data = data[["id","day","airline","destination"]]
# Create DataFrame
# print(data)

# converting data to sql
data.to_sql('sts_dubai_table', conn, if_exists= 'replace')

# fetching all rows
sql1='''select *  from sts_dubai_table;'''
cursor.execute(sql1)
for i in cursor.fetchall():
    print(i)

conn1.commit()
conn1.close()
